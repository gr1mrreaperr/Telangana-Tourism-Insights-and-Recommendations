# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url= "https://en.wikipedia.org/wiki/List_of_districts_of_Telangana"

# %%
page= requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text, 'lxml')
soup= soup.prettify()

# %%
soup
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   List of districts of Telangana - Wikipedia\n  </title>\n  <script>\n   document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feat
# ...

# %%
data= pd.read_html(url)

# %%
df= pd.DataFrame()
data= data[1]

# %%
data= data.set_index('S. No.')

# %%
data.head()
# Out:
#                  Name Headquarters  Area (km2)  Population(2011 census)  \
# S. No.
# 1            Adilabad     Adilabad        4153                   708972
# 2       Kumuram Bheem     Asifabad        4878                   515812
# 3          Mancherial   Mancherial        4016                   807037
# 4              Nirmal       Nirmal        3845                   709418
# 5           Nizamabad    Nizamabad        4288                  1571022
#
#         No.of mandals  Density(per km2)  Urban (%)  Literacy (%)  Sex ratio  \
# S. No.
# 1                  18               171      23.66         63.46        978
# 2                  15               106      16.86         56.72        998
# 3                  18               201      43.85         64.35        977
# 4                  19               185      21.38         57.77       1046
# 5                  27               366      29.58         64.25       1044
#
#         Map
# S. No.
# 1       NaN
# 2       NaN
# ...

# %%
data[["Name","Area (km2)","Population(2011 census)","Density(per km2)","Urban (%)","Literacy (%)","Sex ratio"]]
# Out:
#                       Name  Area (km2)  Population(2011 census)  \
# S. No.
# 1                 Adilabad        4153                   708972
# 2            Kumuram Bheem        4878                   515812
# 3               Mancherial        4016                   807037
# 4                   Nirmal        3845                   709418
# 5                Nizamabad        4288                  1571022
# 6                 Jagitial        2419                   985417
# 7               Peddapalli        2236                   795332
# 8                Kamareddy        3652                   972625
# 9         Rajanna Sircilla        2019                   552037
# 10              Karimnagar        2128                  1005711
# 11             Jayashankar        2293                   416763
# 12              Sangareddy        4403                  1527628
# 13                   Medak        2786                   767428
# ...

# %%
df = data[["Name","Area (km2)","Population(2011 census)","Density(per km2)","Urban (%)","Literacy (%)","Sex ratio"]]

# %%
df= df.iloc[:-1]

# %%
df.tail()
# Out:
#                 Name  Area (km2)  Population(2011 census)  Density(per km2)  \
# S. No.
# 29        Narayanpet        2336                   566874               240
# 30      Mahabubnagar        2738                   919903               340
# 31      Nagarkurnool        6545                   893308               142
# 32        Wanaparthy        2152                   577758               268
# 33         Jogulamba        2928                   609990               208
#
#         Urban (%)  Literacy (%)  Sex ratio
# S. No.
# 29           7.36         49.93       1009
# 30          20.73         60.97        995
# 31          10.19         54.38        968
# 32          15.97         55.67        960
# 33          10.36         49.87        972

# %%
#df.to_csv("telangana_statistics.csv")

# %%
url2= "https://www.telanganatourism.gov.in/partials/about/31-districts-of-telangana.html"

# %%
page= requests.get(url2)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...
